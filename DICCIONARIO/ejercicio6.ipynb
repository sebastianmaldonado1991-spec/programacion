# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario. Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %% [markdown]
# ## Solución

# %%
persona = {}

nombre = input(" Nombre: ")
persona["nombre"] = nombre
print(persona)

while True:
    try:
         edad = int(input("Edad: "))
         break
    except:
        print("dato no válido")
        
persona["edad"] = edad
print(persona)

sexo = input("Sexo: ")
persona["sexo"] = sexo
print(persona)

telefono = input("Telefono: ")
persona["telefono"] = telefono
print(persona)

correo = input("Correo: ")
persona["correo"] = correo
print(persona)
# Out:
# {'nombre': 'seabstian'}
# dato no válido
# {'nombre': 'seabstian', 'edad': 35}
# {'nombre': 'seabstian', 'edad': 35, 'sexo': 'm'}
# {'nombre': 'seabstian', 'edad': 35, 'sexo': 'm', 'telefono': '3333'}
# {'nombre': 'seabstian', 'edad': 35, 'sexo': 'm', 'telefono': '3333', 'correo': 'sdsadada'}

# %%
persona = {}

datos = ["nombre", "edad", "sexo", "telefono", "correo"]

for dato in datos:
    if dato == "edad":
        while True:
            try:
                valor = int(input("ingrese edad: "))
                break
            except ValueError:
                print("error: ingrese un numero valido")
    
    else:
        valor = input(f"ingrese {dato}: ")

    persona[dato] = valor
    print(persona)
# Out:
# {'nombre': 'seba '}
# error: ingrese un numero valido
# {'nombre': 'seba ', 'edad': 45}
# {'nombre': 'seba ', 'edad': 45, 'sexo': 'm'}
# {'nombre': 'seba ', 'edad': 45, 'sexo': 'm', 'telefono': '4567'}
# {'nombre': 'seba ', 'edad': 45, 'sexo': 'm', 'telefono': '4567', 'correo': 'sebastian1991@gmail.com'}
