# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que guarde en una variable el diccionario `{'Euro':'€', 'Dollar':'$', 'Yen':'¥'}`, pregunte al usuario por una divisa y muestre su símbolo o un mensaje de aviso si la divisa no está en el diccionario.

# %% [markdown]
# ## Solución 1

# %%
monedas = {'Euro':'€', 'Dollar':'$', 'Yen':'¥'}
usuario = input("ingrese divisa: ")
usuario = usuario.capitalize()

while  usuario not in monedas.keys():
   
    print("la divisa seleccionada no esta en el diccionario ")
    usuario = input("ingrese divisa: ")
    usuario = usuario.capitalize()
        

print(monedas[usuario])
# Out:
# la divisa seleccionada no esta en el diccionario
# ¥
